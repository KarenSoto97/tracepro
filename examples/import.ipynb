# %%
from tracepro.app import TP_app
from tracepro.element import Element
from tracepro.source import Source

import json
import numpy as np
import matplotlib.pyplot as plt

# %%
working_path =r"C:\Software\tracepro\resultados"
tp_file_name = "pruebas_importar"

tp = TP_app(macro_path=working_path, macro_name="pruebas_importar")
tp.new_file(file_name=tp_file_name, tp_path=working_path)

# %%
lente_ruta = r"C:\Users\prisc\Desktop\FAGOR\Proyecto Lente\lente_karen.stp"

tp.import_piece(file_path=lente_ruta)
tp.name_object(name="lente", object_num=1)
tp.name_surfaces(name="r1", object_num=1, surface_num=0)
tp.name_surfaces(name="r2", object_num=1, surface_num=2)
tp.apply_material(material=("SCHOTT", "F7"), object_num=1)
tp.save_file(file_name="pruebas_importar", tp_path=working_path)
tp.execute()
# Out:
# Successfully completed
# ''

# %%
# tp.delete_macro()
